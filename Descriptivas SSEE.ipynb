# %% [markdown]
# # Descriptivas SSEE

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path="C:/Users/especialistaopep/OneDrive - Ministerio de Educación/Documentos/1 Quick wins + Agenda estratégica 2022/UPP/Equipo plazas/P2. IA Racio/"
#path="D:/OneDrive - Ministerio de Educación/Documentos/1 Quick wins + Agenda estratégica 2022/UPP/Equipo plazas/P2. IA Racio/"

base=pd.read_csv(path+'Base consolidada v2.csv')
base = base.drop(base[base.cod_mod=='S150205'].index)
base.head()
# Out:
# C:\Users\especialistaopep\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (2,33,34,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0  Unnamed: 0.1 cod_mod  codlocal  dir_nom  dir_vac  sub_dir_nom  \
# 0           0             0    2212  427658.0        0        0            0
# 1           1             1  200014   53828.0        0        0            0
# 2           2             2  200022   53833.0        0        0            0
# 3           3             3  200030   53847.0        0        0            0
# 4           4             4  200048   53852.0        0        0            0
#
#    sub_dir_vac  jer_nom  jer_vac  ...       d_prov          d_dist    region  \
# 0            0        0        0  ...  HUANCABAMBA        HUARMACA     PIURA
# 1            0        0        0  ...         GRAU  CHUQUIBAMBILLA  APURIMAC
# 2            0        0        0  ...         GRAU  CHUQUIBAMBILLA  APURIMAC
# 3            0        0        0  ...         GRAU  CHUQUIBAMBILLA  APURIMAC
# 4            0        0        0  ...         GRAU  CHUQUIBAMBILLA  APURIMAC
#
#    jec  ruralidad     vraem     frontera     bilingue  caracteristica  year
# 0  JEC    Rural 1  No Vraem  No frontera  No bilingue        Completo  2016
# 1  NaN    Rural 2  No Vraem  No frontera     Bilingue      Multigrado  2016
# 2  NaN    Rural 2  No Vraem  No frontera     Bilingue      Unidocente  2016
# 3  NaN    Rural 2  No Vraem  No frontera     Bilingue      Multigrado  2016
# 4  NaN    Rural 2  No Vraem  No frontera     Bilingue      Multigrado  2016
#
# [5 rows x 44 columns]

# %%
# Nombres de columnas
my_list = list(base)
print (my_list)
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'cod_mod', 'codlocal', 'dir_nom', 'dir_vac', 'sub_dir_nom', 'sub_dir_vac', 'jer_nom', 'jer_vac', 'doc_nom', 'doc_vac', 'otro_doc_nom', 'otro_doc_vac', 'aux_nom', 'aux_vac', 'cant0 (t)', 'cant1 (t)', 'cant2 (t)', 'cant3 (t)', 'cant4 (t)', 'cant5 (t)', 'cant6 (t)', 'secciones_necesarias', 'req_dir', 'req_sub', 'req_jer', 'req_prof', 'req_aux', 'req_fisica', 'req_aip', 'niv_mod', 'd_niv_mod', 'd_dpto', 'd_prov', 'd_dist', 'region', 'jec', 'ruralidad', 'vraem', 'frontera', 'bilingue', 'caracteristica', 'year']

# %% [markdown]
# Dato: Alumnos en matrícula
# - Inicial: 0 es alumnos en cuna y 5 es alumnos de 5 años. La categoria 6 deberia ser missing
# - Primaria: 0 no existe. Del 1 al 6 es lo usual en primaria
# - Secundaria: Solo esa del 1 al 5. El 0 y el 6 deben ser missing
#
# ** Recordar que en cada proceso se recoge información de hasta 3 periodos anteriores

# %%
# Se hicieron ajustes sobre la BD consolidada:
base['year'] = base['year'].replace([2019],2021)
base['year'] = base['year'].replace([2017],2020)
base['year'] = base['year'].replace([2016],2019)

# %%
base['jec'].value_counts()
# Out:
# JEC    5964
# Name: jec, dtype: int64

# %%
#base.loc[(base['niv_mod']=="F0"), 'year'].value_counts()
#base.loc['niv_mod'=="F0"])base['secciones_norma'].value_counts()

base['ruralidad'].value_counts()
# Out:
# Rural 1    75468
# Rural 2    50776
# Urbano     44294
# Rural 3    22189
# Name: ruralidad, dtype: int64

# %%
base.head()
print(base['cod_mod'].isnull().sum())
# Out:
# 0

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192727 entries, 0 to 192727
# Data columns (total 44 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            192727 non-null  int64
#  1   Unnamed: 0.1          192727 non-null  int64
#  2   cod_mod               192727 non-null  object
#  3   codlocal              128301 non-null  float64
#  4   dir_nom               192727 non-null  int64
#  5   dir_vac               192727 non-null  int64
#  6   sub_dir_nom           192727 non-null  int64
#  7   sub_dir_vac           192727 non-null  int64
#  8   jer_nom               192727 non-null  int64
#  9   jer_vac               192727 non-null  int64
#  10  doc_nom               192727 non-null  int64
#  11  doc_vac               192727 non-null  int64
#  12  otro_doc_nom          192727 non-null  int64
#  13  otro_doc_vac          192727 non-null  int64
#  14  aux_nom               192727 non-null  int64
#  15  aux_vac               192727 non-null  int64
#  16  cant0 (t)             192323 non-null  float64
#  17  cant1 (t)             192323 non-null  float64
#  18  cant2 (t)             192323 non-null  float64
#  19  cant3 (t)             192323 non-null  float64
#  20  cant4 (t)             192323 non-null  float64
#  21  cant5 (t)             192323 non-null  float64
#  22  cant6 (t)             192323 non-null  float64
#  23  secciones_necesarias  192727 non-null  int64
#  24  req_dir               192727 non-null  int64
#  25  req_sub               192727 non-null  int64
#  26  req_jer               192727 non-null  int64
#  27  req_prof              192727 non-null  int64
#  28  req_aux               192727 non-null  int64
#  29  req_fisica            192727 non-null  int64
#  30  req_aip               192727 non-null  int64
#  31  niv_mod               192725 non-null  object
#  32  d_niv_mod             192725 non-null  object
#  33  d_dpto                128317 non-null  object
#  34  d_prov                128317 non-null  object
#  35  d_dist                128317 non-null  object
#  36  region                192725 non-null  object
#  37  jec                   5964 non-null    object
#  38  ruralidad             192727 non-null  object
#  39  vraem                 192727 non-null  object
#  40  frontera              192727 non-null  object
#  41  bilingue              192727 non-null  object
#  42  caracteristica        192727 non-null  object
#  43  year                  192727 non-null  int64
# dtypes: float64(8), int64(23), object(13)
# memory usage: 66.2+ MB

# %% [markdown]
# ## ¿Qué servicio no sigue la norma? ¿por qué?

# %%
## Hallamos los alumnos iniciales, según cuadro N°6 de la norma de racio:

base['alumnos_norma']=0

# Inicial + polidocente + rural
base.loc[((base['niv_mod']=="A1")|(base['niv_mod']=="A2")|(base['niv_mod']=="A3"))&(base['ruralidad']!="Urbano")&(base['caracteristica']=="Completo"), 'alumnos_norma'] = 20

# Inicial + unidocente + rural
base.loc[((base['niv_mod']=="A1")|(base['niv_mod']=="A2")|(base['niv_mod']=="A3"))&(base['ruralidad']!="Urbano")&(base['caracteristica']=="Unidocente"), 'alumnos_norma' ] = 15

# Inicial + polidocente + urbano
base.loc[((base['niv_mod']=="A1")|(base['niv_mod']=="A2")|(base['niv_mod']=="A3"))&(base['ruralidad']=="Urbano"), 'alumnos_norma' ] = 25

# Primaria + polidocente completo + rural
base.loc[(base['niv_mod']=="B0")&(base['ruralidad']!="Urbano")&(base['caracteristica']=="Completo"), 'alumnos_norma' ] = 25

# Primaria + polidocente multigrado + rural
base.loc[(base['niv_mod']=="B0")&(base['ruralidad']!="Urbano")&(base['caracteristica']=="Multigrado"), 'alumnos_norma' ] = 20

# Primaria + unidocente + rural
base.loc[(base['niv_mod']=="B0")&(base['ruralidad']!="Urbano")&(base['caracteristica']=="Unidocente"), 'alumnos_norma' ] = 15

# Primaria + polidocente completo + urbano
base.loc[(base['niv_mod']=="B0")&(base['ruralidad']=="Urbano")&(base['caracteristica']=="Completo"), 'alumnos_norma' ] = 30

# Primaria + polidocente multigrado + urbano
base.loc[(base['niv_mod']=="B0")&(base['ruralidad']=="Urbano")&(base['caracteristica']=="Multigrado"), 'alumnos_norma' ] = 25

# Secundaria + polidocente completo + rural
base.loc[(base['niv_mod']=="F0")&(base['ruralidad']!="Urbano"), 'alumnos_norma' ] = 25

# Secundaria + polidocente completo + urbano
base.loc[(base['niv_mod']=="F0")&(base['ruralidad']=="Urbano"), 'alumnos_norma' ] = 30

# %%
## Ya tenemos los alumnos, ahora hallamos las secciones. Hacemos un bucle por cada # de grado (del 1 al 6):

base['secciones_norma']=0

for x in range(0, 7):
    base[f'secciones_norma_{x}'] = (base[f'cant{x} (t)']) / base[f'alumnos_norma']
    base.replace([np.inf, -np.inf],np.nan, inplace=True) 
    #base[base[f'secciones_norma_{x}'] == inf] = 0
    base[f'secciones_norma_{x}'] = base[f'secciones_norma_{x}'].fillna(0)
    #np.ceil(base[f'secciones_norma_{x}']).astype("int64") 
    base[f'secciones_norma_{x}'] = base[f'secciones_norma_{x}'].apply(lambda X: int(math.ceil(X)))
    #base[f'secciones_norma_{x}'] = math.ceil(base[f'secciones_norma_{x}'])
    base[f'secciones_norma'] = base[f'secciones_norma'] + base[f'secciones_norma_{x}']

# %%
# Hallamos la diferencia entre las necesarias (reales) - las establecidas por la norma
base['secciones_ajuste']=base['secciones_necesarias']-base['secciones_norma']

# %% [markdown]
# ## DISTRIBUCIÓN PARA INICIAL:

# %%
#Intervalo de diferencia de ajuste por grado
    
import math

base_subset = base.loc[(base['niv_mod']=="A1")|(base['niv_mod']=="A2")|(base['niv_mod']=="A3")] 
# De -3.5 a 0.3 secciones faltantes/adicionales. Mayormente faltan secciones.

k = 1 + 3.322 * math.log10(len(base_subset['secciones_ajuste']))
periodos = math.ceil(k)

inf = base_subset['secciones_ajuste'].min()        # Limite inferior del primer intervalo
dif = base_subset['secciones_ajuste'].max()
sup = base_subset['secciones_ajuste'].max()        # Limite superior del último intervalo

intervals = pd.interval_range(
    start=inf,
    end=sup,
    periods=k,
    name="Intervalo",
    closed="left")

df = pd.DataFrame(index=intervals)
df['FreqAbs'] = pd.cut(base_subset['secciones_ajuste'], bins=df.index).value_counts()
df['Marca']  = df.index.mid

df['LimInf'] = df.index.left
df['LimSup'] = df.index.right
df
# Out:
#                                             FreqAbs      Marca     LimInf  \
# Intervalo
# [-23.0, -19.11764705882353)                       4 -21.058824 -23.000000
# [-19.11764705882353, -15.235294117647058)         2 -17.176471 -19.117647
# [-15.235294117647058, -11.352941176470589)       10 -13.294118 -15.235294
# [-11.352941176470589, -7.470588235294118)        35  -9.411765 -11.352941
# [-7.470588235294118, -3.5882352941176485)       357  -5.529412  -7.470588
# [-3.5882352941176485, 0.2941176470588225)     61333  -1.647059  -3.588235
# [0.2941176470588225, 4.1764705882352935)      12566   2.235294   0.294118
# [4.1764705882352935, 8.058823529411764)          16   6.117647   4.176471
# [8.058823529411764, 11.941176470588232)           0  10.000000   8.058824
# [11.941176470588232, 15.823529411764703)          0  13.882353  11.941176
# [15.823529411764703, 19.705882352941174)          0  17.764706  15.823529
# [19.705882352941174, 23.588235294117645)          1  21.647059  19.705882
# [23.588235294117645, 27.470588235294116)          0  25.529412  23.588235
# [27.470588235294116, 31.352941176470587)          5  29.411765  27.470588
# [31.352941176470587, 35.23529411764706)           1  33.294118  31.352941
# [35.23529411764706, 39.11764705882353)            0  37.176471  35.235294
# [39.11764705882353, 43.0)                         0  41.058824  39.117647
#
#                                                LimSup
# Intervalo
# [-23.0, -19.11764705882353)                -19.117647
# [-19.11764705882353, -15.235294117647058)  -15.235294
# [-15.235294117647058, -11.352941176470589) -11.352941
# [-11.352941176470589, -7.470588235294118)   -7.470588
# [-7.470588235294118, -3.5882352941176485)   -3.588235
# [-3.5882352941176485, 0.2941176470588225)    0.294118
# [0.2941176470588225, 4.1764705882352935)     4.176471
# [4.1764705882352935, 8.058823529411764)      8.058824
# [8.058823529411764, 11.941176470588232)     11.941176
# [11.941176470588232, 15.823529411764703)    15.823529
# [15.823529411764703, 19.705882352941174)    19.705882
# [19.705882352941174, 23.588235294117645)    23.588235
# [23.588235294117645, 27.470588235294116)    27.470588
# [27.470588235294116, 31.352941176470587)    31.352941
# [31.352941176470587, 35.23529411764706)     35.235294
# [35.23529411764706, 39.11764705882353)      39.117647
# [39.11764705882353, 43.0)                   43.000000

# %%
sns.boxplot(x="secciones_ajuste",data=base_subset,saturation=1.2,width=0.8,fliersize=5,palette="Set1")
# Out:
# <AxesSubplot:xlabel='secciones_ajuste'>

# %%
base_subset['secciones_ajuste'].hist(bins=15) 
plt.xlabel("Distribución de secciones ajuste")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ## DISTRIBUCIÓN PARA PRIMARIA

# %%
#Intervalo de diferencia de ajuste por grado
    
import math

base_subset = base.loc[base['niv_mod']=="B0"] 
# Mayormente faltan muchas secciones. Promedio: de -15 a -1.5 secciones faltantes. Hay outliers importantes

k = 1 + 3.322 * math.log10(len(base_subset['secciones_ajuste']))
periodos = math.ceil(k)

inf = base_subset['secciones_ajuste'].min()        # Limite inferior del primer intervalo
dif = base_subset['secciones_ajuste'].max()
sup = base_subset['secciones_ajuste'].max()        # Limite superior del último intervalo

intervals = pd.interval_range(
    start=inf,
    end=sup,
    periods=k,
    name="Intervalo",
    closed="left")

df = pd.DataFrame(index=intervals)
df['FreqAbs'] = pd.cut(base_subset['secciones_ajuste'], bins=df.index).value_counts()
df['Marca']  = df.index.mid

df['LimInf'] = df.index.left
df['LimSup'] = df.index.right
df
# Out:
#                                             FreqAbs       Marca      LimInf  \
# Intervalo
# [-55.0, -41.64705882352941)                       3  -48.323529  -55.000000
# [-41.64705882352941, -28.294117647058822)         8  -34.970588  -41.647059
# [-28.294117647058822, -14.941176470588232)       40  -21.617647  -28.294118
# [-14.941176470588232, -1.588235294117645)     69971   -8.264706  -14.941176
# [-1.588235294117645, 11.764705882352942)      19358    5.088235   -1.588235
# [11.764705882352942, 25.117647058823536)          7   18.441176   11.764706
# [25.117647058823536, 38.470588235294116)          1   31.794118   25.117647
# [38.470588235294116, 51.82352941176471)           1   45.147059   38.470588
# [51.82352941176471, 65.1764705882353)             1   58.500000   51.823529
# [65.1764705882353, 78.52941176470588)             0   71.852941   65.176471
# [78.52941176470588, 91.88235294117646)            0   85.205882   78.529412
# [91.88235294117646, 105.23529411764707)           0   98.558824   91.882353
# [105.23529411764707, 118.58823529411765)          1  111.911765  105.235294
# [118.58823529411765, 131.94117647058823)          0  125.264706  118.588235
# [131.94117647058823, 145.29411764705884)          0  138.617647  131.941176
# [145.29411764705884, 158.64705882352942)          0  151.970588  145.294118
# [158.64705882352942, 172.0)                       0  165.323529  158.647059
#
#                                                 LimSup
# Intervalo
# [-55.0, -41.64705882352941)                 -41.647059
# [-41.64705882352941, -28.294117647058822)   -28.294118
# [-28.294117647058822, -14.941176470588232)  -14.941176
# [-14.941176470588232, -1.588235294117645)    -1.588235
# [-1.588235294117645, 11.764705882352942)     11.764706
# [11.764705882352942, 25.117647058823536)     25.117647
# [25.117647058823536, 38.470588235294116)     38.470588
# [38.470588235294116, 51.82352941176471)      51.823529
# [51.82352941176471, 65.1764705882353)        65.176471
# [65.1764705882353, 78.52941176470588)        78.529412
# [78.52941176470588, 91.88235294117646)       91.882353
# [91.88235294117646, 105.23529411764707)     105.235294
# [105.23529411764707, 118.58823529411765)    118.588235
# [118.58823529411765, 131.94117647058823)    131.941176
# [131.94117647058823, 145.29411764705884)    145.294118
# [145.29411764705884, 158.64705882352942)    158.647059
# [158.64705882352942, 172.0)                 172.000000

# %%
sns.boxplot(x="secciones_ajuste",data=base_subset,saturation=1.2,width=0.8,fliersize=5,palette="Set1")
# Out:
# <AxesSubplot:xlabel='secciones_ajuste'>

# %%
base_subset['secciones_ajuste'].hist(bins=15) 
plt.xlabel("Distribución de secciones ajuste")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ## DISTRIBUCIÓN PARA SECUNDARIA

# %%
#Intervalo de diferencia de ajuste por grado
    
import math

base_subset = base.loc[base['niv_mod']=="F0"] 
# De -3.5 a 3.5 secciones adicionales. Mayormente faltan, pero solo ligeramente. Hay outliers importantes

k = 1 + 3.322 * math.log10(len(base_subset['secciones_ajuste']))
periodos = math.ceil(k)

inf = base_subset['secciones_ajuste'].min()        # Limite inferior del primer intervalo
dif = base_subset['secciones_ajuste'].max()
sup = base_subset['secciones_ajuste'].max()        # Limite superior del último intervalo

intervals = pd.interval_range(
    start=inf,
    end=sup,
    periods=k,
    name="Intervalo",
    closed="left")

df = pd.DataFrame(index=intervals)
df['FreqAbs'] = pd.cut(base_subset['secciones_ajuste'], bins=df.index).value_counts()
df['Marca']  = df.index.mid

df['LimInf'] = df.index.left
df['LimSup'] = df.index.right
df
# Out:
#                                             FreqAbs      Marca     LimInf  \
# Intervalo
# [-53.0, -45.93333333333334)                       1 -49.466667 -53.000000
# [-45.93333333333334, -38.86666666666667)          1 -42.400000 -45.933333
# [-38.86666666666667, -31.8)                       8 -35.333333 -38.866667
# [-31.8, -24.733333333333334)                     11 -28.266667 -31.800000
# [-24.733333333333334, -17.66666666666667)        31 -21.200000 -24.733333
# [-17.66666666666667, -10.600000000000001)        89 -14.133333 -17.666667
# [-10.600000000000001, -3.5333333333333314)     1985  -7.066667 -10.600000
# [-3.5333333333333314, 3.5333333333333314)     26135   0.000000  -3.533333
# [3.5333333333333314, 10.599999999999994)        672   7.066667   3.533333
# [10.599999999999994, 17.666666666666657)         54  14.133333  10.600000
# [17.666666666666657, 24.733333333333334)          9  21.200000  17.666667
# [24.733333333333334, 31.799999999999997)          0  28.266667  24.733333
# [31.799999999999997, 38.86666666666666)           3  35.333333  31.800000
# [38.86666666666666, 45.93333333333334)            0  42.400000  38.866667
# [45.93333333333334, 53.0)                         2  49.466667  45.933333
#
#                                                LimSup
# Intervalo
# [-53.0, -45.93333333333334)                -45.933333
# [-45.93333333333334, -38.86666666666667)   -38.866667
# [-38.86666666666667, -31.8)                -31.800000
# [-31.8, -24.733333333333334)               -24.733333
# [-24.733333333333334, -17.66666666666667)  -17.666667
# [-17.66666666666667, -10.600000000000001)  -10.600000
# [-10.600000000000001, -3.5333333333333314)  -3.533333
# [-3.5333333333333314, 3.5333333333333314)    3.533333
# [3.5333333333333314, 10.599999999999994)    10.600000
# [10.599999999999994, 17.666666666666657)    17.666667
# [17.666666666666657, 24.733333333333334)    24.733333
# [24.733333333333334, 31.799999999999997)    31.800000
# [31.799999999999997, 38.86666666666666)     38.866667
# [38.86666666666666, 45.93333333333334)      45.933333
# [45.93333333333334, 53.0)                   53.000000

# %%
sns.boxplot(x="secciones_ajuste",data=base_subset,saturation=1.2,width=0.8,fliersize=5,palette="Set1")
# Out:
# <AxesSubplot:xlabel='secciones_ajuste'>

# %%
base_subset['secciones_ajuste'].hist(bins=15) 
plt.xlabel("Distribución de secciones ajuste")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ## Observaciones 1:
# * Existe un tendencia a tener una cantidad de secciones inferior a la norma.

# %%
# Histograma de frecuencias para ver las observaciones x código modular:

sns.set_style('darkgrid')
sns.countplot(x='niv_mod',data=base,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='niv_mod', ylabel='count'>

# %% [markdown]
# - En promedio, el nivel modular de primaria tiene una mayor brecha de secciones faltantes respecto a los otros niveles modulares. Asimismo, tomar en cuenta que es el nivel modular con más observaciones

# %%
# secciones de ajuste por cod_mod

sns.set_theme(style="darkgrid")
sns.barplot(x='niv_mod', y='secciones_ajuste', data=base)
# Out:
# <AxesSubplot:xlabel='niv_mod', ylabel='secciones_ajuste'>

# %% [markdown]
# ## ¿Qué SSEE no coincide en req/exd con las secciones?

# %% [markdown]
# ### 1. Docentes:
# #### Fórmula: secciones necesarias = (docentes nombrados + docentes vacantes) + requerimiento - excedente

# %%
base['doc_exc'] = 0
base['doc_exc'] = base['doc_nom'] + base['doc_vac'] + base['otro_doc_nom'] + base['otro_doc_vac'] + base['req_prof'] - base['secciones_norma']
#base['doc_exc'].value_counts()

sns.boxplot(x="doc_exc",data=base,saturation=1.2,width=0.8,fliersize=5,palette="Set1")
base
# Out:
#         Unnamed: 0  Unnamed: 0.1  cod_mod  codlocal  dir_nom  dir_vac  \
# 0                0             0     2212  427658.0        0        0
# 1                1             1   200014   53828.0        0        0
# 2                2             2   200022   53833.0        0        0
# 3                3             3   200030   53847.0        0        0
# 4                4             4   200048   53852.0        0        0
# ...            ...           ...      ...       ...      ...      ...
# 192723      192723         64403  1780881       NaN        0        0
# 192724      192724         64404  1780907       NaN        0        0
# 192725      192725         64405  1780915       NaN        0        0
# 192726      192726         64406  1780964       NaN        0        0
# 192727      192727         64407  1781004       NaN        0        0
#
#         sub_dir_nom  sub_dir_vac  jer_nom  jer_vac  ...  secciones_norma  \
# 0                 0            0        0        0  ...                8
# 1                 0            0        0        0  ...                4
# 2                 0            0        0        0  ...                5
# 3                 0            0        0        0  ...                6
# 4                 0            0        0        0  ...                6
# ...             ...          ...      ...      ...  ...              ...
# 192723            0            0        0        0  ...                0
# 192724            0            0        0        0  ...                3
# 192725            0            0        0        0  ...                2
# 192726            0            0        0        0  ...                0
# 192727            0            0        0        0  ...                0
#
#         secciones_norma_0  secciones_norma_1  secciones_norma_2  \
# 0                       0                  2                  2
# 1                       0                  1                  1
# 2                       0                  1                  1
# 3                       0                  1                  1
# 4                       0                  1                  1
# ...                   ...                ...                ...
# 192723                  0                  0                  0
# 192724                  0                  0                  0
# 192725                  0                  0                  0
# 192726                  0                  0                  0
# 192727                  0                  0                  0
#
#         secciones_norma_3  secciones_norma_4  secciones_norma_5  \
# 0                       1                  2                  1
# 1                       1                  0                  0
# 2                       1                  0                  1
# 3                       1                  1                  1
# 4                       1                  1                  1
# ...                   ...                ...                ...
# 192723                  0                  0                  0
# 192724                  1                  1                  1
# 192725                  0                  1                  1
# 192726                  0                  0                  0
# 192727                  0                  0                  0
#
#         secciones_norma_6  secciones_ajuste  doc_exc
# 0                       0                -3       -1
# 1                       1                -3       -2
# 2                       1                -4       -4
# 3                       1                -3       -4
# 4                       1                -5       -4
# ...                   ...               ...      ...
# 192723                  0                 1        1
# 192724                  0                -2       -2
# 192725                  0                -1       -1
# 192726                  0                 2        2
# 192727                  0                 3        2
#
# [192727 rows x 55 columns]

# %% [markdown]
# - Tiende a haber una falta de docentes más que tener excedentes

# %%
#Intervalo de diferencia para excedentes de docentes
    
import math

k = 1 + 3.322 * math.log10(len(base['doc_exc']))
periodos = math.ceil(k)

inf = base['doc_exc'].min()        # Limite inferior del primer intervalo
dif = base['doc_exc'].max()
sup = base['doc_exc'].max()        # Limite superior del último intervalo

intervals = pd.interval_range(
    start=inf,
    end=sup,
    periods=k,
    name="Intervalo",
    closed="left")

df = pd.DataFrame(index=intervals)
df['FreqAbs'] = pd.cut(base['doc_exc'], bins=df.index).value_counts()
df['Marca']  = df.index.mid

df['LimInf'] = df.index.left
df['LimSup'] = df.index.right
df
# Out:
#                                             FreqAbs      Marca     LimInf  \
# Intervalo
# [-34.0, -28.22222222222222)                       5 -31.111111 -34.000000
# [-28.22222222222222, -22.444444444444443)         3 -25.333333 -28.222222
# [-22.444444444444443, -16.666666666666668)       13 -19.555556 -22.444444
# [-16.666666666666668, -10.88888888888889)        61 -13.777778 -16.666667
# [-10.88888888888889, -5.111111111111111)        352  -8.000000 -10.888889
# [-5.111111111111111, 0.6666666666666643)     146730  -2.222222  -5.111111
# [0.6666666666666643, 6.444444444444443)       41184   3.555556   0.666667
# [6.444444444444443, 12.222222222222221)        3150   9.333333   6.444444
# [12.222222222222221, 18.0)                      645  15.111111  12.222222
# [18.0, 23.77777777777778)                       318  20.888889  18.000000
# [23.77777777777778, 29.555555555555557)         121  26.666667  23.777778
# [29.555555555555557, 35.33333333333333)          67  32.444444  29.555556
# [35.33333333333333, 41.111111111111114)          41  38.222222  35.333333
# [41.111111111111114, 46.888888888888886)         23  44.000000  41.111111
# [46.888888888888886, 52.66666666666667)           6  49.777778  46.888889
# [52.66666666666667, 58.44444444444444)            2  55.555556  52.666667
# [58.44444444444444, 64.22222222222221)            5  61.333333  58.444444
# [64.22222222222221, 70.0)                         0  67.111111  64.222222
#
#                                                LimSup
# Intervalo
# [-34.0, -28.22222222222222)                -28.222222
# [-28.22222222222222, -22.444444444444443)  -22.444444
# [-22.444444444444443, -16.666666666666668) -16.666667
# [-16.666666666666668, -10.88888888888889)  -10.888889
# [-10.88888888888889, -5.111111111111111)    -5.111111
# [-5.111111111111111, 0.6666666666666643)     0.666667
# [0.6666666666666643, 6.444444444444443)      6.444444
# [6.444444444444443, 12.222222222222221)     12.222222
# [12.222222222222221, 18.0)                  18.000000
# [18.0, 23.77777777777778)                   23.777778
# [23.77777777777778, 29.555555555555557)     29.555556
# [29.555555555555557, 35.33333333333333)     35.333333
# [35.33333333333333, 41.111111111111114)     41.111111
# [41.111111111111114, 46.888888888888886)    46.888889
# [46.888888888888886, 52.66666666666667)     52.666667
# [52.66666666666667, 58.44444444444444)      58.444444
# [58.44444444444444, 64.22222222222221)      64.222222
# [64.22222222222221, 70.0)                   70.000000

# %%
base['doc_exc'].hist(bins=15) 
plt.xlabel("Distribución de excedentes de docentes")
plt.ylabel("Frecuencia")
plt.show()

# %%
# Excedente de docentes por niv_mod

sns.set_theme(style="darkgrid")
sns.barplot(x='niv_mod', y='doc_exc', data=base)
# Out:
# <AxesSubplot:xlabel='niv_mod', ylabel='doc_exc'>

# %% [markdown]
# ### 2. Auxiliares de educación
#
# #### Inicial: por cada 2 secciones -> 1 auxiliar de educación
# #### Primaria: no hay
# #### Secundaria: por cada 8 secciones -> 1 auxiliar de educación
# #### Fórmula: aux_norma = auxiliares_nombrados + auxiliares vacantes + requerimiento - excedente

# %%
base['aux_norma']=0
base.loc[(base['niv_mod']=="F0"), 'aux_norma' ] = base['secciones_norma'] / 8
base.loc[((base['niv_mod']=="A1")|(base['niv_mod']=="A2")|(base['niv_mod']=="A3")), 'aux_norma'] = base['secciones_norma'] / 2
base[f'aux_norma'] = base[f'aux_norma'].apply(lambda X: int(math.ceil(X)))

base['aux_exc'] = base['aux_nom'] + base['aux_vac'] + base['req_aux'] - base['aux_norma']
sns.boxplot(x="aux_exc",data=base,saturation=1.2,width=0.8,fliersize=5,palette="Set1")
# Out:
# <AxesSubplot:xlabel='aux_exc'>

# %%
#Intervalo de diferencia para excedentes de docentes
    
import math

k = 1 + 3.322 * math.log10(len(base['aux_exc']))
periodos = math.ceil(k)

inf = base['aux_exc'].min()        # Limite inferior del primer intervalo
dif = base['aux_exc'].max()
sup = base['aux_exc'].max()        # Limite superior del último intervalo

intervals = pd.interval_range(
    start=inf,
    end=sup,
    periods=k,
    name="Intervalo",
    closed="left")

df = pd.DataFrame(index=intervals)
df['FreqAbs'] = pd.cut(base['aux_exc'], bins=df.index).value_counts()
df['Marca']  = df.index.mid

df['LimInf'] = df.index.left
df['LimSup'] = df.index.right
df
# Out:
#                                           FreqAbs      Marca     LimInf  \
# Intervalo
# [-8.0, -6.833333333333333)                      7  -7.416667  -8.000000
# [-6.833333333333333, -5.666666666666666)        5  -6.250000  -6.833333
# [-5.666666666666666, -4.5)                     35  -5.083333  -5.666667
# [-4.5, -3.333333333333333)                    113  -3.916667  -4.500000
# [-3.333333333333333, -2.166666666666666)      575  -2.750000  -3.333333
# [-2.166666666666666, -1.0)                  39500  -1.583333  -2.166667
# [-1.0, 0.16666666666666785)                145627  -0.416667  -1.000000
# [0.16666666666666785, 1.333333333333334)     6440   0.750000   0.166667
# [1.333333333333334, 2.5)                      268   1.916667   1.333333
# [2.5, 3.666666666666668)                       80   3.083333   2.500000
# [3.666666666666668, 4.833333333333334)         35   4.250000   3.666667
# [4.833333333333334, 6.0)                       20   5.416667   4.833333
# [6.0, 7.166666666666668)                       15   6.583333   6.000000
# [7.166666666666668, 8.333333333333336)          4   7.750000   7.166667
# [8.333333333333336, 9.5)                        0   8.916667   8.333333
# [9.5, 10.666666666666668)                       0  10.083333   9.500000
# [10.666666666666668, 11.833333333333336)        0  11.250000  10.666667
# [11.833333333333336, 13.0)                      1  12.416667  11.833333
#
#                                              LimSup
# Intervalo
# [-8.0, -6.833333333333333)                -6.833333
# [-6.833333333333333, -5.666666666666666)  -5.666667
# [-5.666666666666666, -4.5)                -4.500000
# [-4.5, -3.333333333333333)                -3.333333
# [-3.333333333333333, -2.166666666666666)  -2.166667
# [-2.166666666666666, -1.0)                -1.000000
# [-1.0, 0.16666666666666785)                0.166667
# [0.16666666666666785, 1.333333333333334)   1.333333
# [1.333333333333334, 2.5)                   2.500000
# [2.5, 3.666666666666668)                   3.666667
# [3.666666666666668, 4.833333333333334)     4.833333
# [4.833333333333334, 6.0)                   6.000000
# [6.0, 7.166666666666668)                   7.166667
# [7.166666666666668, 8.333333333333336)     8.333333
# [8.333333333333336, 9.5)                   9.500000
# [9.5, 10.666666666666668)                 10.666667
# [10.666666666666668, 11.833333333333336)  11.833333
# [11.833333333333336, 13.0)                13.000000

# %%
base['aux_exc'].hist(bins=15) 
plt.xlabel("Distribución de excedente de auxiliares")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# - Tiende a haber una falta de auxiliares más que tener excedentes

# %%
# Excedente de auxiliares por niv_mod

sns.barplot(x='niv_mod', y='aux_exc', data=base)
# Out:
# <AxesSubplot:xlabel='niv_mod', ylabel='aux_exc'>

# %% [markdown]
# - Solo existe un excedente de auxiliares en el nivel inicial A1

# %% [markdown]
# ### 3. Directores
#
# #### 1 director por cada codlocal
# #### Fórmula: dir_norma = directores nombrados + directores vacantes + requerimiento - excedente

# %%
base_collapse = base.groupby(['codlocal'])[['dir_nom','dir_vac','req_dir','doc_nom','doc_vac','doc_exc','secciones_norma','sub_dir_nom','sub_dir_vac','req_sub']].agg(['sum']).reset_index()

base_collapse['dir_norma'] = 1 # 1 por codlocal
#base_collapse.head()

#temp = (base_collapse['cod_mod'] == "S150205" ) ## Un código no permitía convertir
#base_collapse = base_collapse.loc[~temp]

#base_collapse['cod_mod'] = base_collapse['cod_mod'].fillna(0).astype(int)
base_collapse = base_collapse.astype(np.int8)
base_collapse['dir_exc_part1'] = base_collapse['dir_nom'] + base_collapse['dir_vac'] + base_collapse['req_dir'] 
base_collapse['dir_exc'] = base_collapse['dir_exc_part1']- base_collapse['dir_norma']

del base_collapse['dir_exc_part1'] 
import gc
gc.collect()

sns.boxplot(x="dir_exc",data=base_collapse,saturation=1.2,width=0.8,fliersize=5,palette="Set1")
# Out:
# <AxesSubplot:xlabel='dir_exc'>

# %%
#Intervalo de diferencia para excedentes de directores
    
import math

k = 1 + 3.322 * math.log10(len(base_collapse['dir_exc']))
periodos = math.ceil(k)

inf = base_collapse['dir_exc'].min()        # Limite inferior del primer intervalo
dif = base_collapse['dir_exc'].max()
sup = base_collapse['dir_exc'].max()        # Limite superior del último intervalo

intervals = pd.interval_range(
    start=inf,
    end=sup,
    periods=k,
    name="Intervalo",
    closed="left")

df = pd.DataFrame(index=intervals)
df['FreqAbs'] = pd.cut(base_collapse['dir_exc'], bins=df.index).value_counts()
df['Marca']  = df.index.mid

df['LimInf'] = df.index.left
df['LimSup'] = df.index.right
df
# Out:
#               FreqAbs  Marca  LimInf  LimSup
# Intervalo
# [-1.0, -0.5)    41867  -0.75    -1.0    -0.5
# [-0.5, 0.0)         0  -0.25    -0.5     0.0
# [0.0, 0.5)       1044   0.25     0.0     0.5
# [0.5, 1.0)          0   0.75     0.5     1.0
# [1.0, 1.5)       9234   1.25     1.0     1.5
# [1.5, 2.0)          0   1.75     1.5     2.0
# [2.0, 2.5)         58   2.25     2.0     2.5
# [2.5, 3.0)          0   2.75     2.5     3.0
# [3.0, 3.5)        978   3.25     3.0     3.5
# [3.5, 4.0)          0   3.75     3.5     4.0
# [4.0, 4.5)          0   4.25     4.0     4.5
# [4.5, 5.0)          0   4.75     4.5     5.0
# [5.0, 5.5)          4   5.25     5.0     5.5
# [5.5, 6.0)          0   5.75     5.5     6.0
# [6.0, 6.5)          0   6.25     6.0     6.5
# [6.5, 7.0)          0   6.75     6.5     7.0

# %%
base_collapse['dir_exc'].hist(bins=15) 
plt.xlabel("Distribución de excedente de auxiliares")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### 4. Subdirectores
#
# #### No lo pude terminar por falta de RAM :c
#
# #### Se asigna 1 subdirector cada 20 docentes. Si existe docentes < 10, no les corresponde subdirector.
# #### Esto a nivel de código de local, no codmod

# %%
base_collapse['doc_ajuste'] = base_collapse['doc_nom'] + base_collapse['doc_vac']
#base_collapse.info()

#base_collapse.loc[base_collapse['doc_exc']>0, 'doc_ajuste' ] = 'secciones_norma'

#temp = (base_collapse['doc_exc']>0 ) 
#base_collapse = base_collapse.loc[~temp]

#base_temp = base_collapse.loc[base_collapse['doc_exc']>0 , 'doc_ajuste'].to_list()
#base_collapse2 = base_collapse.loc[base_collapse['doc_ajuste'].isin(base_temp)]


base_collapse['sub_norma'] = (base_collapse['doc_ajuste']) / 20
base_collapse.loc[base_collapse['doc_ajuste'] < 10 , 'sub_norma' ] = 0

#base.replace([np.inf, -np.inf],np.nan, inplace=True) 
#base[base[f'secciones_norma_{x}'] == inf] = 0
#base[f'secciones_norma_{x}'] = base[f'secciones_norma_{x}'].fillna(0)
##base_collapse[f'sub_norma'] = base_collapse[f'sub_norma'].apply(lambda X: int(math.ceil(X)))

base_collapse[f'sub_norma'] = base_collapse[f'sub_norma'].apply(lambda X: int(math.ceil(X)))
base_collapse['sub_norma'] = base_collapse['sub_norma'].astype(np.int8)  

base_collapse['sub_exc'] = base_collapse['sub_dir_nom'] + base_collapse['sub_dir_vac'] + base_collapse['req_sub'] - base_collapse['sub_norma']

#base_collapse['sub_exc_p1'] = base_collapse['sub_exc_p1'].astype(np.int8) 
#base_collapse['sub_exc_p2'] = base_collapse['sub_exc_p1'] + base_collapse['req_sub'] ## - base_collapse['sub_norma']
#base_collapse['sub_exc_p2'] = base_collapse['sub_exc_p2'].astype(np.int8)  
#del base_collapse['sub_exc_p11']
#gc.collect()
#base_collapse['sub_exc'] = base_collapse['sub_exc_p2'] - base_collapse['sub_norma']
#del base_collapse['sub_exc_p2']
#gc.collect()

base_collapse
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# C:\Users\ESPECI~1\AppData\Local\Temp/ipykernel_8448/3626168442.py in <module>
#      23 base_collapse['sub_exc_p1'] = base_collapse['sub_exc_p1'].astype(np.int8)
#      24
# ---> 25 base_collapse['sub_exc_p2'] = base_collapse['sub_exc_p1'] + base_collapse['req_sub'] ## - base_collapse['sub_norma']
#      26 base_collapse['sub_exc_p2'] = base_collapse['sub_exc_p2'].astype(np.int8)
#      27
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __radd__(self, other)
#      94     @unpack_zerodim_and_defer("__radd__")
#      95     def __radd__(self, other):
# ---> 96         return self._arith_method(other, roperator.radd)
#      97
#      98     @unpack_zerodim_and_defer("__sub__")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _arith_method(self, other, op)
#    6864         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6865
# -> 6866         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6867         return self._construct_result(new_data)
#    6868
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _dispatch_frame_op(self, right, func, axis)
#    6903             # TODO operate_blockwise expects a manager of the same type
#    6904             with np.errstate(all="ignore"):
# -> 6905                 bm = self._mgr.operate_blockwise(
#    6906                     # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    6907                     # incompatible type "Union[ArrayManager, BlockManager]"; expected
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in operate_blockwise(self, other, array_op)
#    1301         Apply array_op blockwise with another (aligned) BlockManager.
#    1302         """
# -> 1303         return operate_blockwise(self, other, array_op)
#    1304
#    1305     def _equal_values(self: BlockManager, other: BlockManager) -> bool:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\ops.py in operate_blockwise(left, right, array_op)
#      55     res_blks: list[Block] = []
#      56     for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 57         res_values = array_op(lvals, rvals)
#      58         if left_ea and not right_ea and hasattr(res_values, "reshape"):
#      59             res_values = res_values.reshape(1, -1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     222         _bool_arith_check(op, left, right)
#     223
# --> 224         res_values = _na_arithmetic_op(left, right, op)
#     225
#     226     return res_values
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#     168         if is_object_dtype(left) or is_object_dtype(right) and not is_cmp:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     237         if use_numexpr:
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#     241
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     103
#     104         try:
# --> 105             result = ne.evaluate(
#     106                 f"a_value {op_str} b_value",
#     107                 local_dict={"a_value": a_value, "b_value": b_value},
#
# ~\Anaconda3\lib\site-packages\numexpr\necompiler.py in evaluate(ex, local_dict, global_dict, out, order, casting, **kwargs)
#     834     _numexpr_last = dict(ex=compiled_ex, argnames=names, kwargs=kwargs)
#     835     with evaluate_lock:
# --> 836         return compiled_ex(*arguments, **kwargs)
#     837
#     838
#
# MemoryError: Unable to allocate 21.1 GiB for an array with shape (53186, 53186) and data type float64

# %% [markdown]
# ### 4. Jerárquicos
#
# #### Solo para secundaria JER:
#
# #### Por cada 15 secciones: 1 coordinador académico + 1 coordinador pedagógico
# #### Por cada 20 secciones: 1 jefe de laboratorio + 1 jefe de taller

# %%
base['jer_norma_20'] = (base['secciones_norma']) / 20 
base[f'jer_norma_20'] = base[f'jer_norma_20'].apply(lambda X: int(math.ceil(X)))
base['jer_norma_20'] = base['jer_norma_20']*2

base['jer_norma_15'] = (base['secciones_norma']) / 15
base[f'jer_norma_15'] = base[f'jer_norma_15'].apply(lambda X: int(math.ceil(X)))
base['jer_norma_15'] = base['jer_norma_15']*2

base['jer_norma'] = base['jer_norma_20'] + base['jer_norma_15']

base.loc[base['jec'] == "jec" , 'jer_norma' ] = 0 ## Jerárquicos es solo para JER
base.loc[base['niv_mod'] != "F0", 'jer_norma'] = 0 ## Jerárquicos es solo para secundaria

base['jer_exc'] = base['jer_nom'] + base['jer_vac'] - base['jer_norma']

sns.boxplot(x="jer_exc",data=base,saturation=1.2,width=0.8,fliersize=5,palette="Set1")
# Out:
# <AxesSubplot:xlabel='jer_exc'>

# %% [markdown]
# - Es el único puesto que, en promedio, posee un excedente nulo

# %%
#Intervalo de diferencia para excedentes de jerárquicos
    
import math

k = 1 + 3.322 * math.log10(len(base['jer_exc']))
periodos = math.ceil(k)

inf = base['jer_exc'].min()        # Limite inferior del primer intervalo
dif = base['jer_exc'].max()
sup = base['jer_exc'].max()        # Limite superior del último intervalo

intervals = pd.interval_range(
    start=inf,
    end=sup,
    periods=k,
    name="Intervalo",
    closed="left")

df = pd.DataFrame(index=intervals)
df['FreqAbs'] = pd.cut(base['jer_exc'], bins=df.index).value_counts()
df['Marca']  = df.index.mid

df['LimInf'] = df.index.left
df['LimSup'] = df.index.right
df
# Out:
#                                              FreqAbs      Marca     LimInf  \
# Intervalo
# [-21.0, -19.11111111111111)                        3 -20.055556 -21.000000
# [-19.11111111111111, -17.22222222222222)           9 -18.166667 -19.111111
# [-17.22222222222222, -15.333333333333334)         21 -16.277778 -17.222222
# [-15.333333333333334, -13.444444444444445)        59 -14.388889 -15.333333
# [-13.444444444444445, -11.555555555555555)        91 -12.500000 -13.444444
# [-11.555555555555555, -9.666666666666668)        280 -10.611111 -11.555556
# [-9.666666666666668, -7.777777777777779)        1122  -8.722222  -9.666667
# [-7.777777777777779, -5.888888888888889)        1947  -6.833333  -7.777778
# [-5.888888888888889, -4.0)                       546  -4.944444  -5.888889
# [-4.0, -2.1111111111111107)                    24565  -3.055556  -4.000000
# [-2.1111111111111107, -0.22222222222222143)      230  -1.166667  -2.111111
# [-0.22222222222222143, 1.6666666666666643)    163839   0.722222  -0.222222
# [1.6666666666666643, 3.5555555555555536)           7   2.611111   1.666667
# [3.5555555555555536, 5.444444444444443)            7   4.500000   3.555556
# [5.444444444444443, 7.333333333333332)             0   6.388889   5.444444
# [7.333333333333332, 9.222222222222221)             0   8.277778   7.333333
# [9.222222222222221, 11.111111111111107)            0  10.166667   9.222222
# [11.111111111111107, 13.0)                         0  12.055556  11.111111
#
#                                                 LimSup
# Intervalo
# [-21.0, -19.11111111111111)                 -19.111111
# [-19.11111111111111, -17.22222222222222)    -17.222222
# [-17.22222222222222, -15.333333333333334)   -15.333333
# [-15.333333333333334, -13.444444444444445)  -13.444444
# [-13.444444444444445, -11.555555555555555)  -11.555556
# [-11.555555555555555, -9.666666666666668)    -9.666667
# [-9.666666666666668, -7.777777777777779)     -7.777778
# [-7.777777777777779, -5.888888888888889)     -5.888889
# [-5.888888888888889, -4.0)                   -4.000000
# [-4.0, -2.1111111111111107)                  -2.111111
# [-2.1111111111111107, -0.22222222222222143)  -0.222222
# [-0.22222222222222143, 1.6666666666666643)    1.666667
# [1.6666666666666643, 3.5555555555555536)      3.555556
# [3.5555555555555536, 5.444444444444443)       5.444444
# [5.444444444444443, 7.333333333333332)        7.333333
# [7.333333333333332, 9.222222222222221)        9.222222
# [9.222222222222221, 11.111111111111107)      11.111111
# [11.111111111111107, 13.0)                   13.000000

# %%
base['jer_exc'].hist(bins=15) 
plt.xlabel("Distribución de excedente de auxiliares")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ## Matriz de Correlaciones

# %%
base['vraem_d'] = 1
base.loc[(base['vraem']=="No Vraem"), 'vraem_d' ] = 0

base['frontera_d'] = 1
base.loc[(base['frontera']=="No frontera"), 'frontera_d' ] = 0

base['ruralidad_d'] = 0
base.loc[(base['ruralidad']=="Rural 1"), 'ruralidad_d' ] = 3
base.loc[(base['ruralidad']=="Rural 2"), 'ruralidad_d' ] = 2
base.loc[(base['ruralidad']=="Rural 3"), 'ruralidad_d' ] = 1

base['bilingue_d'] = 1
base.loc[(base['bilingue']=="No bilingue"), 'bilingue_d' ] = 0

base_corr = base[["doc_exc", "aux_exc", "jer_exc", "vraem_d", "frontera_d", "bilingue_d", "ruralidad_d", "secciones_ajuste"]]
base_corr.head()

# No Vraem
# No frontera
# No bilingue
# Rural 3, Rural 2, Rural 1
# Out:
#    doc_exc  aux_exc  jer_exc  vraem_d  frontera_d  bilingue_d  ruralidad_d  \
# 0       -1       -1       -4        0           0           0            3
# 1       -2        0        0        0           0           1            2
# 2       -4        0        0        0           0           1            2
# 3       -4        0        0        0           0           1            2
# 4       -4        0        0        0           0           1            2
#
#    secciones_ajuste
# 0                -3
# 1                -3
# 2                -4
# 3                -3
# 4                -5

# %%
#data = {'A': [45,37,42,35,39],
#        'B': [38,31,26,28,33],
#        'C': [10,15,17,21,12]
#        }

#df_corr = pd.DataFrame(df_corr)

# corrMatrix = df.corr()
sns.heatmap(base_corr.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.show()

# %% [markdown]
# - Existe una alta correlación directa entre las IIEE que tienen excedente de docentes y secciones
# - Existe una alta correlación directa entre las IIEE con alto gradiente de ruralidad y poseer EIB
# - Existe una correlación indirecta entre los excedentes de puestos jerárquicos (menor brecha) y puestos docentes
# - Existe una correlación indirecta entre la ruralidad y la brecha de puestos docentes
